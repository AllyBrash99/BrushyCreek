# %%
import pickle
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(20,10)})
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm
import math
from scipy.stats import f
#%pip install numpy_indexed
import datetime
from sklearn.model_selection import train_test_split
from scipy.stats import gaussian_kde

# %%
df = pd.read_csv("CleansedDataSets/DecemberCleansed.csv")

df['timestamp']= pd.to_datetime(df['timestamp'])
df = df.set_index('timestamp')
df = df.sort_index()



df.head(10)
# Out:
#                          MDM current (A)  Actual Volume Flow (Nm3/sec)  \
# timestamp
# 2021-12-02 18:37:40.386        94.536850                      7.060305
# 2021-12-02 18:39:40.367        94.468178                      7.119567
# 2021-12-02 18:42:10.682        94.010384                      7.151681
# 2021-12-02 18:43:40.946        94.639862                      7.087503
# 2021-12-02 18:47:41.411        94.285057                      7.078812
# 2021-12-02 18:48:10.975        94.090492                      7.130202
# 2021-12-02 19:34:15.386        94.067604                      7.057298
# 2021-12-02 19:41:15.995        94.445290                      6.992270
# 2021-12-02 19:41:45.988        94.021828                      7.021164
# 2021-12-02 19:42:15.929        93.804367                      7.080849
#
#                          VDV Pos [%] (%)  IGV Pos [%] (%)  \
# timestamp
# 2021-12-02 18:37:40.386             91.0             83.0
# 2021-12-02 18:39:40.367             91.0             83.0
# 2021-12-02 18:42:10.682             91.0             83.0
# 2021-12-02 18:43:40.946             91.0             83.0
# 2021-12-02 18:47:41.411             91.0             83.0
# 2021-12-02 18:48:10.975             91.0             83.0
# 2021-12-02 19:34:15.386             91.0             84.0
# 2021-12-02 19:41:15.995             91.0             84.0
# 2021-12-02 19:41:45.988             91.0             84.0
# 2021-12-02 19:42:15.929             91.0             85.0
#
#                          Isentropic His (J/kg)       Phi
# timestamp
# 2021-12-02 18:37:40.386           48705.644034  0.131286
# 2021-12-02 18:39:40.367           48604.120087  0.132388
# 2021-12-02 18:42:10.682           48471.782963  0.132985
# 2021-12-02 18:43:40.946           48395.646182  0.131791
# 2021-12-02 18:47:41.411           48446.150652  0.131464
# 2021-12-02 18:48:10.975           48453.207041  0.132585
# 2021-12-02 19:34:15.386           49316.562661  0.131230
# 2021-12-02 19:41:15.995           49555.963557  0.129809
# 2021-12-02 19:41:45.988           49754.546436  0.130230
# 2021-12-02 19:42:15.929           49837.254658  0.131668

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x=df.index, y=df["Phi"])

# %%
plt.scatter(x=df.index, y=df["MDM current (A)"])

# %%
plt.scatter(x=df.index, y=df["Isentropic His (J/kg)"])

# %%
plt.scatter(x=df.index, y=df["IGV Pos [%] (%)"])

# %%
plt.scatter(x=df.index, y=df["VDV Pos [%] (%)"])

# %%
subset = df.loc[df.index < "2021-12-17"]
subset1 = df.loc[df.index > "2021-12-21"]

# %%
sns.heatmap(subset.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(subset1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
subset1 = subset1.loc[subset1["MDM current (A)"]>80]
subset1 = subset1.loc[subset1["Phi"]>0.11]
subset1 = subset1.loc[subset1["Phi"]<0.135]
subset1 = subset1.loc[subset1["Isentropic His (J/kg)"]>48000]

# %%
plt.scatter(x=subset1.index, y=subset1["Phi"])

# %%
plt.scatter(x=subset1.index, y=subset1["MDM current (A)"])

# %%
plt.scatter(x=subset1.index, y=subset1["Isentropic His (J/kg)"])

# %%
plt.scatter(x=subset1.index, y=subset1["IGV Pos [%] (%)"])

# %%
plt.scatter(x=subset1.index, y=subset1["VDV Pos [%] (%)"])

# %%
sns.heatmap(subset1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
subset1.to_csv("Kmeans/DataSets/decembermanuallycleansed.csv")
